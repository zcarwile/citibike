# %% [markdown]
# ### Citibike Trip Data

# %%
import pandas as pd

# %%
# Data file for May 2016
df = pd.read_csv("201605-citibike-tripdata.csv")

# %%
df.tail(5)
# Out:
#          tripduration           starttime           stoptime  \
# 1212275           309  5/31/2016 23:59:21  6/1/2016 00:04:31
# 1212276           985  5/31/2016 23:59:21  6/1/2016 00:15:46
# 1212277           674  5/31/2016 23:59:35  6/1/2016 00:10:50
# 1212278           533  5/31/2016 23:59:37  6/1/2016 00:08:31
# 1212279           457  5/31/2016 23:59:43  6/1/2016 00:07:20
#
#          start station id                 start station name  \
# 1212275               397           Fulton St & Clermont Ave
# 1212276               531             Forsyth St & Broome St
# 1212277               128           MacDougal St & Prince St
# 1212278               281  Grand Army Plaza & Central Park S
# 1212279               477                    W 41 St & 8 Ave
#
#          start station latitude  start station longitude  end station id  \
# 1212275               40.684157               -73.969223            3049
# 1212276               40.718939               -73.992663             402
# 1212277               40.727103               -74.002971             276
# 1212278               40.764397               -73.973715             477
# 1212279               40.756405               -73.990026             457
#
#                  end station name  end station latitude  \
# 1212275  Cambridge Pl & Gates Ave             40.684880
# 1212276        Broadway & E 22 St             40.740343
# 1212277   Duane St & Greenwich St             40.717488
# 1212278           W 41 St & 8 Ave             40.756405
# 1212279        Broadway & W 58 St             40.766953
#
#          end station longitude  bikeid    usertype  birth year  gender
# 1212275             -73.963040   20805  Subscriber      1987.0       2
# 1212276             -73.989551   22010  Subscriber      1966.0       1
# 1212277             -74.010455   25086  Subscriber      1998.0       1
# 1212278             -73.990026   14903  Subscriber      1970.0       1
# 1212279             -73.981693   15362  Subscriber      1975.0       1

# %% [markdown]
# ### Bike Availability Data

# %%
import json
from urllib.request import urlopen

response = urlopen("https://feeds.citibikenyc.com/stations/stations.json")

j = response.read().decode('utf-8')
s = json.loads(j)
station_json = s['stationBeanList']
station_df = pd.DataFrame(station_json)

# %%
#station_df.tail(5)
station_df[station_df['stationName'].str.startswith('E 72')]
# Out:
#     altitude  availableBikes  availableDocks city    id landMark  \
# 401                        2              40       3139
# 416                       19              19       3156
#
#       lastCommunicationTime   latitude location  longitude postalCode  \
# 401  2016-11-16 11:34:01 AM  40.771183          -73.964094
# 416  2016-11-16 11:35:43 AM  40.766638          -73.953483
#
#              stAddress1 stAddress2         stationName  statusKey statusValue  \
# 401  E 72 St & Park Ave             E 72 St & Park Ave          1  In Service
# 416  E 72 St & York Ave             E 72 St & York Ave          1  In Service
#
#     testStation  totalDocks
# 401       False          43
# 416       False          39

# %%
station_df = station_df[station_df["statusValue"] == "In Service"]
p72_df = station_df[station_df["stationName"] == "E 72 St & Park Ave"]
p72_df.head()
# Out:
#     altitude  availableBikes  availableDocks city    id landMark  \
# 401                        2              40       3139
#
#       lastCommunicationTime   latitude location  longitude postalCode  \
# 401  2016-11-16 11:34:01 AM  40.771183          -73.964094
#
#              stAddress1 stAddress2         stationName  statusKey statusValue  \
# 401  E 72 St & Park Ave             E 72 St & Park Ave          1  In Service
#
#     testStation  totalDocks
# 401       False          43

# %%
# Write table to file
import datetime

fname = "citibike_" + datetime.datetime.strftime(datetime.datetime.now(),"%Y%m%d%H%M%S") + ".json"
with open(fname,"w") as f:
    f.write(j)

# %% [markdown]
# ### Mapping Bike Availability

# %%
# Courtesy of:
# http://www.gal-systems.com/2011/07/convert-coordinates-between-web.html

import math

def lon_to_web_mercator(lon):

    num = lon * 0.017453292519943295;
    x = 6378137.0 * num;
    mercatorX = x;
    return mercatorX

def lat_to_web_mercator(lat):

    a = lat * 0.017453292519943295;
    mercatorY = 3189068.5 * math.log((1.0 + math.sin(a)) / (1.0 - math.sin(a)));

    return mercatorY

# %%
X = station_df['longitude'].map(lon_to_web_mercator)
Y = station_df['latitude'].map(lat_to_web_mercator)

# %%
from bokeh.plotting import figure, output_notebook, show

output_notebook()

x_range=(-8255000,-8225000)
y_range=(4963000,4983000)

def base_plot(tools='pan,wheel_zoom,reset,hover',plot_width=900, plot_height=600, **plot_args):
    p = figure(tools=tools, plot_width=plot_width, plot_height=plot_height,
        x_range=x_range, y_range=y_range, outline_line_color=None,
        min_border=0, min_border_left=0, min_border_right=0,
        min_border_top=0, min_border_bottom=0, **plot_args)
    
    p.axis.visible = True
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    return p
    
options = dict(line_color=None, fill_color='blue', size=5)

from IPython.core.display import HTML, display
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="08b16b14-15ef-4896-be74-d3fe1d5dfb8d">Loading BokehJS ...</span>
#     </div>
# <style>.container { width:90% !important; }</style>

# %%
from bokeh.tile_providers import STAMEN_TONER
output_notebook()

p = base_plot()
p.add_tile(STAMEN_TONER)
#p.circle(mercatorX, mercatorY)
p.circle(X,Y,size=station_df['availableBikes'])
show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4aadd69d-805c-472f-aa8a-2c899895a0c4">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="e7835c0a-6742-42f9-b250-dbd41f8b3c8c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e7835c0a-6742-42f9-b250-dbd41f8b3c8c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e7835c0a-6742-42f9-b250-dbd41f8b3c8c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f1820aea-d135-4b6e-8819-acd77d45e352":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"790eb26c-245b-4cad-a541-2d786da466d2","type":"Circle"},{"attributes":{"attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>.Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>","url":"http://tile.stamen.com/toner/{Z}/{X}/{Y}.png"},"id":"fdff95ec-c81f-45aa-928d-a4b243613f6e","type":"WMTSTileSource"},{"attributes":{},"id":"9ec0e708-eb2e-4fa4-93e9-c9c2c784689b","type":"BasicTicker"},{"attributes":{},"id":"1bfa896f-9887-4751-b0af-69efbd0fdad8","type":"BasicTicker"},{"attributes":{"plot":{"id":"1f3c48cc-daf5-47e6-be82-5d76be75b1b1","subtype":"Figure","type":"Plot"}},"id":"27ea940b-addc-43df-b25d-3db12a2457c2","type":"ResetTool"},{"attributes":{"below":[{"id":"696dbbf8-192a-42bc-9e74-154b3be2196b","type":"LinearAxis"}],"left":[{"id":"605f08e7-7142-4104-8468-85c099941e66","type":"LinearAxis"}],"min_border":0,"min_border_bottom":0,"min_border_left":0,"min_border_right":0,"min_border_top":0,"outline_line_color":{"value":null},"plot_width":900,"renderers":[{"id":"696dbbf8-192a-42bc-9e74-154b3be2196b","type":"LinearAxis"},{"id":"1e233421-fc56-4186-8c5e-5a8ec3cacd42","type":"Grid"},{"id":"605f08e7-7142-4104-8468-85c099941e66","type":"LinearAxis"},{"id":"c50d8d4c-4bda-44f4-a73b-ed4495ecb576","type":"Grid"},{"id":"5cb6fe5f-3fb7-4eae-8125-49183e37cfd9","type":"TileRenderer"},{"id":"09f4898f-9fd6-47be-9a62-f0d1200516bf","type":"GlyphRenderer"}],"tool_events":{"id":"fcaf3e42-82a7-4f25-8ffc-49af84945989","type":"ToolEvents"},"tools":[{"id":"5144c4c7-29cc-4e45-8e7c-9cf8732c64ab","type":"PanTool"},{"id":"88b6018c-ad53-46ca-803b-8f5a7ce9ee4b","type":"WheelZoomTool"},{"id":"27ea940b-addc-43df-b25d-3db12a2457c2","type":"ResetTool"},{"id":"e57ee857-abb4-469e-9b49-77ea2d70ca88","type":"HoverTool"}],"x_range":{"id":"2b839b5d-8ab4-4ee3-8b7f-c65e236ae4a3","type":"Range1d"},"y_range":{"id":"02b3f34c-50ff-4a4d-8b09-2095c7e1f816","type":"Range1d"}},"id":"1f3c48cc-daf5-47e6-be82-5d76be75b1b1","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"c3ef02ab-1eb9-4f0b-b9bf-8bd1c1707d8d","type":"BasicTickFormatter"},"plot":{"id":"1f3c48cc-daf5-47e6-be82-5d76be75b1b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"1bfa896f-9887-4751-b0af-69efbd0fdad8","type":"BasicTicker"}},"id":"696dbbf8-192a-42bc-9e74-154b3be2196b","type":"LinearAxis"},{"attributes":{"formatter":{"id":"141af0ea-1432-4b3f-9848-3997cfac9539","type":"BasicTickFormatter"},"plot":{"id":"1f3c48cc-daf5-47e6-be82-5d76be75b1b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"9ec0e708-eb2e-4fa4-93e9-c9c2c784689b","type":"BasicTicker"}},"id":"605f08e7-7142-4104-8468-85c099941e66","type":"LinearAxis"},{"attributes":{"plot":{"id":"1f3c48cc-daf5-47e6-be82-5d76be75b1b1","subtype":"Figure","type":"Plot"}},"id":"5144c4c7-29cc-4e45-8e7c-9cf8732c64ab","type":"PanTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"903858ca-f5a0-4538-a5d7-df96050f1606","type":"Circle"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"1f3c48cc-daf5-47e6-be82-5d76be75b1b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"1bfa896f-9887-4751-b0af-69efbd0fdad8","type":"BasicTicker"}},"id":"1e233421-fc56-4186-8c5e-5a8ec3cacd42","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","size"],"data":{"size":[2,32,20,22,30,12,3,9,27,22,14,15,26,9,30,10,42,0,33,43,22,47,47,0,22,27,7,14,12,37,51,20,12,5,2,3,30,5,19,31,11,4,0,13,26,26,19,48,11,37,3,37,35,5,4,27,27,0,12,26,0,18,3,9,1,33,28,55,1,41,41,10, ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[17]</strong>&gt;</code></p>

# %% [markdown]
# ### Weather Data
#
# We use forecast.io.  Sign up for an API key good for 1000 calls per day.  This is more than adequate for polling every 5 minutes

# %%
weather_raw = urlopen("https://api.forecast.io/forecast/62b3f08596594954c4856e61610736ee/40.71,-74.01")
weather_json = json.loads(weather_raw.read().decode('utf-8'))

# %%
weather_minutely = weather_json['minutely']['data']
minutely_df = pd.DataFrame(weather_minutely)
minutely_df.head(5)
# Out:
#    precipIntensity  precipProbability        time
# 0                0                  0  1479315120
# 1                0                  0  1479315180
# 2                0                  0  1479315240
# 3                0                  0  1479315300
# 4                0                  0  1479315360

# %%
weather_hourly = weather_json['hourly']['data']
hourly_df = pd.DataFrame(weather_hourly)
hourly_df.head(10)
# Out:
#    apparentTemperature  cloudCover  dewPoint  humidity                 icon  \
# 0                52.60        0.04     38.55      0.59            clear-day
# 1                57.22        0.05     41.59      0.56            clear-day
# 2                58.96        0.08     42.00      0.53            clear-day
# 3                60.51        0.12     42.88      0.52            clear-day
# 4                60.84        0.12     43.50      0.53            clear-day
# 5                59.54        0.17     43.96      0.56            clear-day
# 6                57.18        0.33     43.70      0.61  partly-cloudy-night
# 7                55.37        0.37     43.51      0.64  partly-cloudy-night
# 8                53.87        0.35     42.95      0.66  partly-cloudy-night
# 9                52.48        0.36     42.68      0.69  partly-cloudy-night
#
#     ozone  precipIntensity  precipProbability  pressure        summary  \
# 0  275.60                0                  0   1008.38          Clear
# 1  273.35                0                  0   1008.39          Clear
# 2  271.58                0                  0   1008.38          Clear
# 3  270.86                0                  0   1008.37          Clear
# 4  270.63                0                  0   1008.41          Clear
# 5  270.82                0                  0   1008.64          Clear
# 6  271.66                0                  0   1009.31  Partly Cloudy
# 7  272.92                0                  0   1010.09  Partly Cloudy
# 8  273.95                0                  0   1010.78  Partly Cloudy
# 9  274.46                0                  0   1011.27  Partly Cloudy
#
#    temperature        time  visibility  windBearing  windSpeed
# 0        52.60  1479312000        9.66          262       5.09
# 1        57.22  1479315600        9.78          248       6.34
# 2        58.96  1479319200        9.86          245       6.88
# 3        60.51  1479322800        9.92          243       6.76
# 4        60.84  1479326400        9.96          240       6.42
# 5        59.54  1479330000        9.98          238       5.78
# 6        57.18  1479333600       10.00          234       6.15
# 7        55.37  1479337200        9.67          244       6.03
# 8        53.87  1479340800        9.50          262       6.07
# 9        52.48  1479344400        9.39          271       5.97

# %%
weather_daily = weather_json['daily']['data']
daily_df = pd.DataFrame(weather_daily)
daily_df.head(7)
# Out:
#    apparentTemperatureMax  apparentTemperatureMaxTime  apparentTemperatureMin  \
# 0                   60.84                  1479326400                   40.69
# 1                   60.93                  1479412800                   43.05
# 2                   63.02                  1479495600                   39.38
# 3                   65.66                  1479585600                   39.92
# 4                   41.10                  1479672000                   29.69
# 5                   38.44                  1479762000                   23.41
# 6                   44.32                  1479852000                   25.41
#
#    apparentTemperatureMinTime  cloudCover  dewPoint  humidity  \
# 0                  1479286800        0.24     41.42      0.70
# 1                  1479380400        0.04     43.16      0.72
# 2                  1479466800        0.01     41.76      0.70
# 3                  1479614400        0.31     43.81      0.71
# 4                  1479639600        0.24     34.58      0.70
# 5                  1479726000        0.01     27.29      0.63
# 6                  1479812400        0.40     27.97      0.61
#
#                   icon  moonPhase   ozone    ...      sunriseTime  sunsetTime  \
# 0  partly-cloudy-night       0.58  271.86    ...       1479296760  1479332321
# 1            clear-day       0.62  263.57    ...       1479383231  1479418676
# 2            clear-day       0.65  242.94    ...       1479469701  1479505032
# 3                 wind       0.69  244.02    ...       1479556171  1479591391
# 4                 rain       0.72  295.54    ...       1479642641  1479677751
# 5                 snow       0.76  291.15    ...       1479729110  1479764113
# 6  partly-cloudy-night       0.79  269.30    ...       1479815578  1479850478
#
#    temperatureMax  temperatureMaxTime temperatureMin  temperatureMinTime  \
# 0           60.84          1479326400          44.52          1479290400
# 1           60.93          1479412800          46.44          1479380400
# 2           63.02          1479495600          43.05          1479466800
# 3           65.66          1479585600          45.02          1479553200
# 4           48.96          1479672000          40.23          1479636000
# 5           45.66          1479762000          34.70          1479729600
# 6           47.41          1479852000          34.07          1479812400
#
#          time  visibility  windBearing  windSpeed
# 0  1479272400        9.72          260       5.91
# 1  1479358800        9.75          315       6.72
# 2  1479445200       10.00          322       4.28
# 3  1479531600       10.00          270       6.12
# 4  1479618000         NaN          287      25.77
# 5  1479704400         NaN          301      18.77
# 6  1479790800         NaN          283       8.29
#
# [7 rows x 27 columns]

# %%
# this is what we'd want to dump to a file

weather_currently = weather_json['currently']
print(json.dumps(weather_currently, indent=4))
# Out:
# {
#     "temperature": 56.64,
#     "summary": "Clear",
#     "humidity": 0.56,
#     "visibility": 9.76,
#     "precipProbability": 0,
#     "precipIntensity": 0,
#     "nearestStormDistance": 55,
#     "ozone": 273.63,
#     "windBearing": 249,
#     "windSpeed": 6.17,
#     "pressure": 1008.39,
#     "nearestStormBearing": 11,
#     "time": 1479315150,
#     "icon": "clear-day",
#     "cloudCover": 0.05,
#     "apparentTemperature": 56.64,
#     "dewPoint": 41.21
# }

# %% [markdown]
# ### Batch processing of weather data

# %%
# once we have a bunch of files, we can stitch them together into a matrix

import os

weather_dir = "/Users/zcarwile/Documents/content/sales_engineering_demos/citibike/weatherData/"

i = 1
for file in os.listdir(weather_dir):
    
    timestamp = file.replace("weather_","").replace(".txt","")
    year = int(timestamp[0:4])
    month = int(timestamp[4:6])
    day = int(timestamp[6:8])
    hour = int(timestamp[8:10])
    minute =  int(timestamp[10:12])

    with open(weather_dir + file,"r") as f:
    
        weather_currently = eval(f.read())
    
        if i == 1:
            cols = ['TS_year','TS_month','TS_day','TS_hour','TS_minute']
            for key, value in weather_currently.items():
                cols.append(key)
            weather_df = pd.DataFrame(columns=cols)

        row = [year,month,day,hour,minute]
        for col in cols:
            if "TS_" not in col:
                row.append(weather_currently[col])
        weather_df.loc[i] = row          

        i = i + 1

weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-f38424f95088> in <module>()
#       6
#       7 i = 1
# ----> 8 for file in os.listdir(weather_dir):
#       9
#      10     timestamp = file.replace("weather_","").replace(".txt","")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/zcarwile/Documents/content/sales_engineering_demos/citibike/weatherData/'
